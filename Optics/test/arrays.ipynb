# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Nx,Ny = 7,5
dx,dy = 1,1
xa = np.arange(0.5,Nx)*dx
ya = np.arange(0.5,Ny)*dy
X,Y = np.meshgrid(xa,ya)
RSQ = X**2+Y**2
#RSQ = RSQ<5**2
plt.imshow(RSQ)

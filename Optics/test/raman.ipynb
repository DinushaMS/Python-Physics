# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
T = 300 # temperature in K
kB = 1.380649e-23 #Boltzmann constant in J/K
nu_R = 1000 #vibrational level energy in 1/cm
c = 3e10 #speed of light in cm/s
h = 6.63e-34 #Plank's constant in Js
wl_L = 532e-7 #laser wavelength in cm

Is_by_Ias = (nu_R-2*np.pi/wl_L)**4/(nu_R+2*np.pi/wl_L)**4*np.exp(h*nu_R*c/kB/T)
Is_by_Ias
# Out:
# 113.78964101868931
